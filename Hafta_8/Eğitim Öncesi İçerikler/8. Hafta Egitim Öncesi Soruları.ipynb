# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
def urunBilgisi():
    urunAdi = input("Ürün adı: ")
    urunFiyati = input("Ürün fiyatı: ")

# Bu bilgiler urunler.txt dosyasına eklenir. Dosya yoksa yeni bir dosya oluşturulur, varsa mevcut dosyanın sonuna eklenir.

    with open("urunler.txt", "a", encoding="utf-8") as dosya:
        dosya.write(f"Ürün: {urunAdi}, Fiyat: {urunFiyati} TL \n")

    print(f"{urunAdi} ürünü {urunFiyati} TL olarak kaydedildi.")

urunBilgisi()
# Out:
# patates ürünü 10 TL olarak kaydedildi.

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
def degisim(dosya_adi, eski_kelime, yeni_kelime):
    try: 
        #dosyayı oku
        with open(dosya_adi, "r", encoding="utf-8") as dosya:
            icerik = dosya.read()
            
        #eski kelimenin yerine yeni kelimeyi yaz
        yeni_icerik = icerik.replace(eski_kelime, yeni_kelime)
        
        #dosyanın yeni halini yaz
        with open(dosya_adi, "w", encoding="utf-8") as dosya:
            dosya.write(yeni_icerik)

        print(f"{eski_kelime} kelimesi {yeni_kelime} kelimesiyle yer değiştirdi.")

    except FileNotFoundError:
        print(f"{dosya_adi} bulunamadı.")
    
eski_kelime = input("Değiştirmek istediğiniz ürünü giriniz: ")
yeni_kelime = input("Yeni ürünü giriniz:")

degisim("urunler.txt", eski_kelime, yeni_kelime)
# Out:
# patates kelimesi çilek kelimesiyle yer değiştirdi.

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
class Vehicle:
    def __init__(self, name, speed, mileage):
        self.name = name
        self.speed = speed
        self.mileage = mileage
    
    def display_info(self):
        return f"Name: {self.name} Speed: {self.speed} Mileage: {self.mileage}"
    
class Bus(Vehicle):
    pass 

school_bus = Bus("School Volvo", 180, 12)

print(school_bus.display_info())
# Out:
# Name: School Volvo Speed: 180 Mileage: 12
